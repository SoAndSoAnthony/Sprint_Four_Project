# %% [markdown]
# Project Scope:
#
# The purpose of this particular project is to showcase different kinds of graphs with the help of our plotly.express library. We will first conduct some exploratory data analysis to see if there are any missing data. The numpy library would come in handy just in case. This notebook is part of a bigger project, in that the main scope is to further apply it into a sample web app for later.

# %%
#Getting the necessary libraries possible
import pandas as pd
import numpy as np
import streamlit as st
import plotly.express as px

# %%
#loading our dataset
cars_us = pd.read_csv("C:\\Users\\Anthony\\Desktop\\python_folder\\software_dev_project_1\\vehicles_us.csv")
#creating a new column titled 'manufacturer', which gets the first word of the 'model' column
cars_us['manufacturer'] = cars_us['model'].apply(lambda x:
                                                 x.split()[0])

# %%
#A sample of what we're dealing with...
cars_us.sample(15)
# Out:
#        price  model_year                       model  condition  cylinders  \
# 16338  10965      2007.0                  ford f-150  excellent        8.0
# 19920  19500      2017.0                  honda cr-v   like new        4.0
# 8156    2600      2004.0            hyundai santa fe       fair        6.0
# 36321   2499      2012.0                  ford f-150  excellent        6.0
# 6195   28500      2006.0                  ford f-250  excellent        8.0
# 45147  15000      2017.0              honda civic lx  excellent        4.0
# 23454   1500      1999.0         jeep grand cherokee       fair        8.0
# 2970    5000      2001.0  chevrolet silverado 2500hd       good        8.0
# 222     2750      2006.0              honda civic lx       good        4.0
# 22242  13991      2015.0           chevrolet equinox       good        4.0
# 37281  24000      2016.0           toyota highlander       good        6.0
# 7039   14950      2013.0  chevrolet silverado 2500hd  excellent        8.0
# 26090   4500      2011.0                    kia soul       good        4.0
# 34387   8000      2007.0              toyota corolla  excellent        4.0
# 31527   8995      2012.0                 ford escape  excellent        6.0
#
#          fuel  odometer transmission       type paint_color  is_4wd  \
# 16338     gas   81000.0    automatic     pickup         NaN     1.0
# 19920     gas   12000.0    automatic        SUV       black     1.0
# 8156      gas       NaN    automatic        SUV         NaN     1.0
# 36321     gas  120179.0    automatic     pickup         NaN     1.0
# 6195   diesel   74300.0    automatic     pickup       white     1.0
# 45147     gas   41000.0    automatic      sedan         NaN     NaN
# 23454     gas   21900.0    automatic        SUV        blue     1.0
# 2970   diesel  241000.0    automatic     pickup         red     NaN
# 222       gas     200.0       manual      sedan       black     NaN
# 22242     gas   76642.0    automatic        SUV      custom     1.0
# 37281     gas   53000.0    automatic        SUV        grey     1.0
# 7039      gas  151067.0    automatic      truck         NaN     1.0
# 26090     gas  131230.0    automatic  hatchback         NaN     NaN
# 34387     gas   69362.0    automatic      sedan       white     NaN
# 31527     gas   91881.0    automatic      wagon      silver     1.0
#
#       date_posted  days_listed manufacturer
# 16338  2018-12-12           91         ford
# 19920  2018-12-21          118        honda
# 8156   2018-05-06            1      hyundai
# 36321  2018-11-23           35         ford
# 6195   2018-08-30           56         ford
# 45147  2019-03-14           13        honda
# 23454  2018-12-07           11         jeep
# 2970   2018-11-24           22    chevrolet
# 222    2018-07-06           41        honda
# 22242  2018-08-24           35    chevrolet
# 37281  2019-03-28           35       toyota
# 7039   2018-08-18           25    chevrolet
# 26090  2019-01-21           65          kia
# 34387  2018-08-08           34       toyota
# 31527  2019-03-30           44         ford

# %%
#What's under the hood?
cars_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
#  13  manufacturer  51525 non-null  object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 5.5+ MB

# %% [markdown]
# Thus far, the columns with missing values are as follows:
# - model_year (We could replace those missing values with the mode)
# - cylinders (We could replace those missing values with the median value within that column)
# - odometer (We could replace those missing values with the median value as well)
# - paint_color (We can replace the missing value with the phrase 'Unknown')
# - is_4wd (assuming the missing values are not 4 wheel drive)

# %%
#How do we know if there are columns with missing values in 'model_year' and 'odometer'?
cars_us[(cars_us['model_year'].isna()) & (cars_us['odometer'].isna())]
# Out:
#        price  model_year                        model  condition  cylinders  \
# 159    23300         NaN  nissan frontier crew cab sv       good        NaN
# 260    14975         NaN               toyota 4runner       good        6.0
# 370     4700         NaN                     kia soul       good        NaN
# 586    26000         NaN                  toyota rav4   like new        4.0
# 659     8400         NaN             volkswagen jetta       good        4.0
# ...      ...         ...                          ...        ...        ...
# 51195  21999         NaN                     ram 2500       good        6.0
# 51222   1000         NaN                     acura tl       good        6.0
# 51257   6500         NaN               toyota corolla       good        4.0
# 51295   3850         NaN              hyundai elantra  excellent        4.0
# 51399   4400         NaN                  kia sorento  excellent        6.0
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# 159       gas       NaN        other  pickup        grey     1.0  2018-07-24
# 260       gas       NaN    automatic     SUV      silver     NaN  2018-05-13
# 370       gas       NaN       manual   sedan       white     NaN  2019-01-14
# 586       gas       NaN    automatic     SUV         NaN     NaN  2018-08-09
# 659    diesel       NaN       manual   wagon         NaN     NaN  2018-10-22
# ...       ...       ...          ...     ...         ...     ...         ...
# 51195  diesel       NaN    automatic   truck       white     1.0  2018-05-10
# 51222     gas       NaN    automatic   sedan        grey     NaN  2018-12-09
# 51257     gas       NaN    automatic   sedan       white     NaN  2018-10-16
# 51295     gas       NaN    automatic   sedan      silver     NaN  2019-03-16
# 51399     gas       NaN    automatic     SUV      silver     NaN  2018-08-21
#
#        days_listed manufacturer
# 159             73       nissan
# 260             57       toyota
# 370             50          kia
# 586             29       toyota
# 659             37   volkswagen
# ...            ...          ...
# 51195           35          ram
# 51222           23        acura
# 51257           75       toyota
# 51295           83      hyundai
# 51399           23          kia
#
# [549 rows x 14 columns]

# %% [markdown]
# 549 entries where we have neither mileage nor model year. Not a big bother for a dataframe of 51,525 entries though...

# %% [markdown]
# Assuming the missing values in the 'is_4wd' are cars without 4-wheel drive, we can go ahead a replace said missing value with 0.

# %%
#Assuming the missing values in the 'is_4wd' are cars without 4-wheel drive, we can go ahead a replace said missing value with 0
cars_us['is_4wd'] = cars_us['is_4wd'].fillna(0)

# %%
#Replacing missing paint colors with the term 'unknown' 
cars_us['paint_color'] = cars_us['paint_color'].fillna('Unknown')

# %%
#Replacing missing values of the model year with the mode
cars_us['model_year'] = cars_us['model_year'].fillna(cars_us['model_year'].mode())

# %%
#Replacing missing values of cylinders with the median
cars_us['cylinders'] = cars_us['cylinders'].fillna(cars_us['cylinders'].median())

# %%
#Replacing missing values within the odometer with the median
cars_us['odometer'] = cars_us['odometer'].fillna(cars_us['odometer'].median())

# %% [markdown]
# That should take care of any data discrepancies.

# %%
#How many brands are on that list?
cars_us['manufacturer'].value_counts()
# Out:
# ford             12672
# chevrolet        10611
# toyota            5445
# honda             3485
# ram               3316
# jeep              3281
# nissan            3208
# gmc               2378
# subaru            1272
# dodge             1255
# hyundai           1173
# volkswagen         869
# chrysler           838
# kia                585
# cadillac           322
# buick              271
# bmw                267
# acura              236
# mercedes-benz       41
# Name: manufacturer, dtype: int64

# %% [markdown]
# Ford and Chevrolet are the two most common brands on this list. But how do their prices compare against each other?

# %%
#What are the kinds of fuel options available?
cars_us['fuel'].value_counts()
# Out:
# gas         47288
# diesel       3714
# hybrid        409
# other         108
# electric        6
# Name: fuel, dtype: int64

# %%
#And the available qualities of the vehicle?
cars_us['condition'].value_counts()
# Out:
# excellent    24773
# good         20145
# like new      4742
# fair          1607
# new            143
# salvage        115
# Name: condition, dtype: int64

# %%
st.header('Vehicle types by manufacturer')
#Our histogram
veh_type = px.histogram(cars_us,x='manufacturer', 
                   color='type')
#Showing the histogram with Streamlit
st.write(veh_type)
# Out:
# 2023-05-07 22:25:40.473
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Anthony\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
st.header('Histrogram of condition vs model_year')
#And here's the histogram:
con_vs_yr = px.histogram(cars_us, x='model_year', 
                         color='type')
#Let's show that histogram
st.write(con_vs_yr)

# %%
st.header('Scatterplot Example')
example = px.scatter(cars_us,x='price',y='odometer',color='type')
st.write(example)

# %%
example
#While this does raise an error, we can see the scatterplot graph.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File c:\Users\Anthony\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\Anthony\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'type=SUV<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'SUV',
#               'marker': {'color': '#000001', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'SUV',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 9400, 15990, 11500, ...,  6995,  7995,  8999], dtype=int64),
#               'xaxis': 'x',
#               'y': array([145000., 109473., 104174., ..., 157000., 111088., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=pickup<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'pickup',
#               'marker': {'color': '#000002', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pickup',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([25500,  1500, 19500, ..., 29500, 17999, 12000], dtype=int64),
#               'xaxis': 'x',
#               'y': array([ 88705., 113000., 128413., ..., 113000., 154000., 228000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=sedan<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'sedan',
#               'marker': {'color': '#000003', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sedan',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 5500, 14900, 14990, ...,  3950,  7455,  6300], dtype=int64),
#               'xaxis': 'x',
#               'y': array([110000.,  80903.,  57954., ..., 128000., 139573., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=truck<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'truck',
#               'marker': {'color': '#000004', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'truck',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 7500,  8000,  6200, ...,  2995, 15900,  2000], dtype=int64),
#               'xaxis': 'x',
#               'y': array([180000., 234000.,  69698., ..., 206257., 113000., 122000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=coupe<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'coupe',
#               'marker': {'color': '#000005', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'coupe',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([29800,  2400, 19700, ..., 12990, 21600, 11750], dtype=int64),
#               'xaxis': 'x',
#               'y': array([ 57413., 277564.,  35807., ..., 118659.,  19579., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=van<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'van',
#               'marker': {'color': '#000006', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'van',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([34900, 13900,  5995, ...,  9995, 11495,  3900], dtype=int64),
#               'xaxis': 'x',
#               'y': array([113000.,  62711., 113000., ...,  68768., 100258., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=convertible<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'convertible',
#               'marker': {'color': '#000007', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'convertible',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([30000, 13000, 17999, ..., 18995,  7995,  9950], dtype=int64),
#               'xaxis': 'x',
#               'y': array([ 51000.,  85104.,  30469., ...,  62196., 104124.,  44435.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=hatchback<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'hatchback',
#               'marker': {'color': '#000008', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'hatchback',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([3000, 3950, 8595, ..., 7995, 4800, 5980], dtype=int64),
#               'xaxis': 'x',
#               'y': array([200412., 137882.,  99630., ..., 106250., 113000., 121778.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=wagon<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'wagon',
#               'marker': {'color': '#000009', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'wagon',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 3650,  8999, 10997, ...,  6900,  5995,  4995], dtype=int64),
#               'xaxis': 'x',
#               'y': array([113000., 122964., 113000., ..., 113000., 124161., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=mini-van<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'mini-van',
#               'marker': {'color': '#000010', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'mini-van',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 4975,  4999,  6500, ...,  4595, 26500,  4950], dtype=int64),
#               'xaxis': 'x',
#               'y': array([205000., 129448., 119156., ..., 199201.,  71659., 150000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=other<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'other',
#               'marker': {'color': '#000001', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'other',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([10495, 12495, 16995, ...,  4500,  2000,  5895], dtype=int64),
#               'xaxis': 'x',
#               'y': array([111337.,  45694., 113000., ..., 172000., 237000., 113000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=offroad<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'offroad',
#               'marker': {'color': '#000002', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'offroad',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([18000,  1200, 21400, ...,  2500,  6000,  2500], dtype=int64),
#               'xaxis': 'x',
#               'y': array([ 92770., 181226.,  95750., ..., 288662., 104000., 242000.]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'type=bus<br>price=%{x}<br>odometer=%{y}<extra></extra>',
#               'legendgroup': 'bus',
#               'marker': {'color': '#000003', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bus',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([10500, 28990, 10500,  4995, 28990, 28990,  4995, 28990, 28990, 28990,
#                            4995, 28990,  4995, 28990,  6997,  7900,  7500,  4995, 10000,  6997,
#                            6997, 28990, 28990, 28990], dtype=int64),
#               'xaxis': 'x',
#               'y': array([142539.,  17037., 142539., 225000.,  17037.,  17037., 225000.,  17037.,
#                            17037.,  17037., 225000.,  17037., 225000.,  17037., 248135., 142000.,
#                           109705., 225000.,  50000., 248135., 248135., 113000.,  17037.,  17037.]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'type'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'price'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'odometer'}}}
# })

# %% [markdown]
# Graph assessment:
#
# From what we can gather, the median of the odometer appears as a small line of dots. These dots mark as 113k miles as our median for our odometer. On another note, the greatest concentration within this scatterplot appears to peak from around 415,000 miles on the y-axis and at about roughly 60,000 dollars on the x-axis.

# %%
st.header('Price comparision between two different manufacturers')      
manufac_list = sorted(cars_us['manufacturer'].unique())                 #Our list of car manufacturers
manufacturer_1 = st.selectbox(                                          #Gets users inputs from dropdown menu
                            label= 'Choose the first manufacturer',     #Title of the select box
                            options=manufac_list,                       #Options listed in select box
                            index=manufac_list.index('ford'))           #Default pre-selected option

manufacturer_2 = st.selectbox(                                          #Repeat practice for second dropdown
                            label= 'Choose the second manufacturer',     
                            options=manufac_list,                       
                            index=manufac_list.index('chevrolet'))
mask_filter = (cars_us['manufacturer'] == manufacturer_1) | (cars_us['manufacturer'] == manufacturer_2)
cars_us_filtered = cars_us[mask_filter]
normalize = st.checkbox('Normalize histogram', value=True)
if normalize:
    histnorm = 'percent'
else:
    histnorm = None
st.write(px.histogram(cars_us_filtered,
                    x='price',
                    nbins=30,
                    color='manufacturer',
                    histnorm=histnorm,
                    barmode='overlay'))
